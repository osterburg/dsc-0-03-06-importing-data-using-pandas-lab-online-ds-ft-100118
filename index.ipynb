# %% [markdown]
# # Importing Data Using Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" (content covers loading data from a currupted csv file!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Import data from csv files and Excel files
# * Understand and explain key arguments for imports
# * Save information to csv and Excel files
# * Access data within a Pandas DataFrame (print() and .head())

# %% [markdown]
# #  Loading Files with Summary or Meta Data
#
# Load either of the files Zipcode_Demos.csv or Zipcode_Demos.xlsx. What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.
#
# All data files are stored in a folder titled 'Data'.

# %%
#Your code here
import pandas as pd

zip_xls = pd.ExcelFile('Data/Zipcode_Demos.xlsx')
print(zip_xls.sheet_names)
df = zip_xls.parse(sheet_name=0)
df.head()
# Out:
# ['Sheet1']
#                     0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Average Statistics        NaN        NaN        NaN        NaN        NaN
# 1                 NaN          0        NaN        NaN        NaN        NaN
# 2   JURISDICTION NAME    10005.8        NaN        NaN        NaN        NaN
# 3  COUNT PARTICIPANTS        9.4        NaN        NaN        NaN        NaN
# 4        COUNT FEMALE        4.8        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 36  \
# 0        NaN        NaN        NaN        NaN     ...             NaN
# 1        NaN        NaN        NaN        NaN     ...             NaN
# 2        NaN        NaN        NaN        NaN     ...             NaN
# 3        NaN        NaN        NaN        NaN     ...             NaN
# 4        NaN        NaN        NaN        NaN     ...             NaN
#
#   Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 43 Unnamed: 44 Unnamed: 45
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 46 columns]

# %%
df = pd.read_csv('Data/Zipcode_Demos.csv')
df.head()
# Out:
#    0  Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1                 NaN          0        NaN        NaN        NaN
# 1  2   JURISDICTION NAME    10005.8        NaN        NaN        NaN
# 2  3  COUNT PARTICIPANTS        9.4        NaN        NaN        NaN
# 3  4        COUNT FEMALE        4.8        NaN        NaN        NaN
# 4  5      PERCENT FEMALE      0.404        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 37  \
# 0        NaN        NaN        NaN        NaN     ...             NaN
# 1        NaN        NaN        NaN        NaN     ...             NaN
# 2        NaN        NaN        NaN        NaN     ...             NaN
# 3        NaN        NaN        NaN        NaN     ...             NaN
# 4        NaN        NaN        NaN        NaN     ...             NaN
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 44 Unnamed: 45 Unnamed: 46
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Level Up (Optional)
#
# ### Loading Corrupt CSV files
#
# Occassionally, you encountered some really ill formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is suppossed to use quotes to differentiate between the commas denoting fields and commas within those fields themselves. For example, we could have a table like this:
#
# ReviewerID,Rating,N_reviews,Review,VenueID
# 123456,4,137,This restuarant was pretty good, we had a great time.,98765
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text):
# "ReviewerID","Rating","N_reviews","Review","VenueID"
# "123456","4","137","This restuarant was pretty good, we had a great time.","98765"

# %% [markdown]
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled Yelp_Reviews_corrupt.csv. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
#Hint: here's a useful programming pattern to use.
try:
    #do something
except Exception as e:
    #handle your exception e

# %%
#Your code here
try:
    df = pd.read_csv('Data/Yelp_Reviews_Corrupt.csv')
except Exception as e:
    print(e)
# Out:
# Error tokenizing data. C error: Expected 10 fields in line 2331, saw 11

# %%
# df = pd.read_csv('Data/Yelp_Reviews_corrupt.csv', sep='delimiter', engine='python', skiprows=20, nrows=1, header=None)
df = pd.read_csv('Data/Yelp_Reviews_corrupt.csv', nrows=10, header=1)
df.head()
# Out:
#     1  pomGBqfbxcqPv14c3XH-ZQ  0  2012-11-13  0.1  dDl8zu1vWPdKGihJrwQbpw  5  \
# 0   2  jtQARsP6P-LbkyjbO1qNGg  1  2014-10-23    1  LZp4UX5zK3e-c5ZGSeo3kA  1
# 1   4  Ums3gaP2qM3W1XcA5r6SsQ  0  2014-09-05    0  jsDu6QEJHbwP2Blom1PLCA  5
# 2   5  vgfcTvK81oD4r50NMjU2Ag  0  2011-02-25    0  pfavA0hr3nyqO61oupj-lA  1
# 3  10  yFumR3CWzpfvTH2FCthvVw  0  2016-06-15    0  STiFMww2z31siPY7BWNC2g  5
# 4  11  UBv8heCQR0RPnUQG0zkXIQ  0  2016-09-23    0  HkYqGb0Gplmmk-xlHTRBoA  1
#
#   I love this place! My fiance And I go here atleast once a week. The portions are huge! Food is amazing. I love their carne asada. They have great lunch specials... Leticia is super nice and cares about what you think of her restaurant. You have to try their cheese enchiladas too the sauce is different And amazing!!!  \
# 0  Terrible. Dry corn bread. Rib tips were all fa...
# 1  Delicious healthy food. The steak is amazing. ...
# 2  This place sucks. The customer service is horr...
# 3  I have been an Emerald Club member for a numbe...
# 4  The score should be negative. Its HORRIBLE. Th...
#
#    0.2  msQe1u7Z_XuqjGoqhB0J5g
# 0    3  msQe1u7Z_XuqjGoqhB0J5g
# 1    0  msQe1u7Z_XuqjGoqhB0J5g
# 2    2  msQe1u7Z_XuqjGoqhB0J5g
# 3    0  TlvV-xJhmh7LCwJYXkV-cg
# 4    0  NhOc64RsrTT1Dls50yYW8g

# %%
for i in range(1500, 2500):
    try:
        df = pd.read_csv('Data/Yelp_Reviews_Corrupt.csv', nrows=i)
    except:
        print('Error at line: {}'.format(i))
        break
        
df1 = pd.read_csv('Data/Yelp_Reviews_Corrupt.csv', nrows=i-1)
print(len(df))
df1.head()
# Out:
# Error at line: 1962
# 1961
#   Unnamed: 0             business_id cool        date  funny  \
# 0          1  pomGBqfbxcqPv14c3XH-ZQ    0  2012-11-13    0.0
# 1          2  jtQARsP6P-LbkyjbO1qNGg    1  2014-10-23    1.0
# 2          4  Ums3gaP2qM3W1XcA5r6SsQ    0  2014-09-05    0.0
# 3          5  vgfcTvK81oD4r50NMjU2Ag    0  2011-02-25    0.0
# 4         10  yFumR3CWzpfvTH2FCthvVw    0  2016-06-15    0.0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw    5.0
# 1  LZp4UX5zK3e-c5ZGSeo3kA    1.0
# 2  jsDu6QEJHbwP2Blom1PLCA    5.0
# 3  pfavA0hr3nyqO61oupj-lA    1.0
# 4  STiFMww2z31siPY7BWNC2g    5.0
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...     0.0
# 1  Terrible. Dry corn bread. Rib tips were all fa...     3.0
# 2  Delicious healthy food. The steak is amazing. ...     0.0
# 3  This place sucks. The customer service is horr...     2.0
# 4  I have been an Emerald Club member for a numbe...     0.0
#
#                   user_id
# 0  msQe1u7Z_XuqjGoqhB0J5g
# 1  msQe1u7Z_XuqjGoqhB0J5g
# 2  msQe1u7Z_XuqjGoqhB0J5g
# 3  msQe1u7Z_XuqjGoqhB0J5g
# 4  TlvV-xJhmh7LCwJYXkV-cg
